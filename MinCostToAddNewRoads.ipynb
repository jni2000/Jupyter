# %%
"""
There are N cities numbered from 1 to N.

You are given connections, where each connections[i] = [city1, city2, cost] represents the cost to 
connect city1 and city2together. (A connection is bidirectional: connecting city1 and city2 is the 
same as connecting city2 and city1.)

Return the minimum cost so that for every pair of cities, there exists a path of connections 
(possibly of length 1) that connects those two cities together. The cost is the sum of the connection 
costs used. If the task is impossible, return -1.

Input: N = 3, connections = [[1,2,5],[1,3,6],[2,3,1]]
Output: 6

Input: N = 4, connections = [[1,2,3],[3,4,4]]
Output: -1
"""
# Python3 code to find out minimum cost  
# path to connect all the cities  
def bulidCityMatrix(n, connections):
    if n > 0:
        city = [[0 for j in range(n)] for i in range(n)]
        for connection in connections:
            city[connection[0]-1][connection[1]-1] = connection[2]
    else:
        city = None
    return city

def fullyConnected(n, connections):
    connected = True
    if n > 0:
        # count number of unique connections if connections in input is not "unique"
        if len(connections) < n-1:
            connected = False
    else:
        connected= False
    return connected

# Function to find out minimum valued  
# node among the nodes which are not  
# yet included in MST  
def minnode(n, keyval, mstset): 
    mini = 999999999999
    mini_index = None
      
    # Loop through all the values of  
    # the nodes which are not yet  
    # included in MST and find the  
    # minimum valued one. 
    for i in range(n): 
        if (mstset[i] == False and 
            keyval[i] < mini):  
            mini = keyval[i] 
            mini_index = i 
    return mini_index 
  
# Function to find out the MST and  
# the cost of the MST.  
def findcost(n, city): 
    if city is None:
        return -1
    # Array to store the parent  
    # node of a particular node.  
    parent = [None] * n 
      
    # Array to store key value  
    # of each node.  
    keyval = [None] * n  
      
    # Boolean Array to hold bool  
    # values whether a node is 
    # included in MST or not.  
    mstset = [None] * n 
      
    # Set all the key values to infinite and  
    # none of the nodes is included in MST. 
    for i in range(n): 
        keyval[i] = 9999999999999
        mstset[i] = False
      
    # Start to find the MST from node 0.  
    # Parent of node 0 is none so set -1.  
    # key value or minimum cost to reach  
    # 0th node from 0th node is 0.  
    parent[0] = -1
    keyval[0] = 0
      
    # Find the rest n-1 nodes of MST. 
    for i in range(n - 1): 
      
        # First find out the minimum node  
        # among the nodes which are not yet  
        # included in MST.  
        u = minnode(n, keyval, mstset)  
      
        # Now the uth node is included in MST.  
        mstset[u] = True
      
        # Update the values of neighbor  
        # nodes of u which are not yet  
        # included in MST.  
        for v in range(n): 
            if (city[u][v] and mstset[v] == False and 
                city[u][v] < keyval[v]):  
                keyval[v] = city[u][v]  
                parent[v] = u 
      
    # Find out the cost by adding  
    # the edge values of MST.  
    cost = 0
    for i in range(1, n): 
        cost += city[parent[i]][i]  
    return cost 

def findMinCost(n, connections):
    cost = 0
    if n > 0:
        if fullyConnected(n, connections):
            city = bulidCityMatrix(n3, connections)
            cost = findcost(n, city)
        else:
            cost = -1
    else:
        cost = -1
    return cost
    
# Driver code
if __name__ == '__main__': 
  
    # Input 1  
    n1 = 5
    city1 = [[0, 1, 2, 3, 4],  
             [1, 0, 5, 0, 7],  
             [2, 5, 0, 6, 0], 
             [3, 0, 6, 0, 0],  
             [4, 7, 0, 0, 0]]  
    print(findcost(n1, city1))  
      
    # Input 2  
    n2 = 6
    city2 = [[0, 1, 1, 100, 0, 0], 
             [1, 0, 1, 0, 0, 0],  
             [1, 1, 0, 0, 0, 0],  
             [100, 0, 0, 0, 2, 2], 
             [0, 0, 0, 2, 0, 2],  
             [0, 0, 0, 2, 2, 0]]  
    print(findcost(n2, city2))
    
    #input 3  
    connections = [[1,2,5],[1,3,6],[2,3,1]]
    n3 = 3
    print(findMinCost(n3, connections))

    #input 4 
    connections = [[1,2,3],[3,4,4]]
    print(findMinCost(n4, connections))
# Out:
# 10
# 106
# 6
# -1
